# %% [markdown]
# # IANCU Summer Camp for New Students 2026
#
# ## Introductory Python Programming 4: "Simulating interacting galaxies"
#
# ### Instructor: Kinoshita Daisuke
#
# ### July 2026

# %% [markdown]
# # 0. Installation of Python interpreter

# %%
# Run this cell to install Python 3.14

# !apt update
# !apt upgrade
# !apt install python3.14 python3.14-dev python3.14-full libpython3.14-dev
# !update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.14 1
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3.14 get-pip.py

# %%
# Run this cell to check the version of Python interpreter and pip command

# !python3.14 --version
# !pip --version

# %%
# Run this cell to install external Python packages.

# !pip install matplotlib matplotlib-inline numpy scipy rebound

# %% [markdown]
# # 1. Downloading a set of sample Python scripts for this session

# %%
# Run this cell to download a set of sample Python scripts for this course.

# !git clone https://github.com/kinoshitadaisuke/iancu_camp202607.git

# %%
# Run this cell to move to the directory for this session.

# %cd iancu_camp202607/py04

# %%
# Run this cell to show a list of files for this session.

# !ls -lF

# %% [markdown]
# # 2. Star and planet 1

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_00_00.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_00_00.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.bin

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_00_01.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_00_01.py

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_00_02.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_00_02.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.data

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_00_03.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_00_03.py

# %%
# Run this cell to find newly created files.

# !ls -lF star_planet_1 | head -20

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_00_04.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_00_04.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.mp4

# %%
# Playing MP4 movie file

# importing IPython.display
import IPython.display

# playing MP4 movie file
IPython.display.Video ('star_planet_1.mp4')

# %%
# Downloading MP4 movie file to local computer

#
# If previous cell fails to play MP4 movie, then download MP4 movie file to your local computer and play the movie file on your local computer.
#

# importing google.colab
import google.colab.files

# downloading MP4 movie file
google.colab.files.download ('star_planet_1.mp4')

# %% [markdown]
# # 3. Star and planet 2

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_01_00.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_01_00.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.bin

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_01_01.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_01_01.py

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_01_02.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_01_02.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.data

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_01_03.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_01_03.py

# %%
# Run this cell to find newly created files.

# !ls -lF star_planet_2 | head -20

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_01_04.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_01_04.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.mp4

# %%
# Playing MP4 movie file

# importing IPython.display
import IPython.display

# playing MP4 movie file
IPython.display.Video ('star_planet_2.mp4')

# %%
# Downloading MP4 movie file to local computer

#
# If previous cell fails to play MP4 movie, then download MP4 movie file to your local computer and play the movie file on your local computer.
#

# importing google.colab
import google.colab.files

# downloading MP4 movie file
google.colab.files.download ('star_planet_2.mp4')

# %% [markdown]
# # 4. Sirius system

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_02_00.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_02_00.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.bin

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_02_01.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_02_01.py

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_02_02.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_02_02.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.data

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_02_03.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_02_03.py

# %%
# Run this cell to find newly created files.

# !ls -lF sirius_system | head -20

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_02_04.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_02_04.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.mp4

# %%
# Playing MP4 movie file

# importing IPython.display
import IPython.display

# playing MP4 movie file
IPython.display.Video ('sirius_system.mp4')

# %%
# Downloading MP4 movie file to local computer

#
# If previous cell fails to play MP4 movie, then download MP4 movie file to your local computer and play the movie file on your local computer.
#

# importing google.colab
import google.colab.files

# downloading MP4 movie file
google.colab.files.download ('sirius_system.mp4')

# %% [markdown]
# # 5. Figure-8 solution of 3-body problem

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_03_00.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_03_00.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.bin

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_03_01.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_03_01.py

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_03_02.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_03_02.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.data

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_03_03.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_03_03.py

# %%
# Run this cell to find newly created files.

# !ls -lF 3body_figure8 | head -20

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_03_04.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_03_04.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.mp4

# %%
# Playing MP4 movie file

# importing IPython.display
import IPython.display

# playing MP4 movie file
IPython.display.Video ('3body_figure8.mp4')

# %%
# Downloading MP4 movie file to local computer

#
# If previous cell fails to play MP4 movie, then download MP4 movie file to your local computer and play the movie file on your local computer.
#

# importing google.colab
import google.colab.files

# downloading MP4 movie file
google.colab.files.download ('3body_figure8.mp4')

# %% [markdown]
# # 6. Modelling a galaxy

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_04_00.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_04_00.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.bin

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_04_01.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_04_01.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.data

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_04_02.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_04_02.py

# %%
# Run this cell to find newly created files.

# !ls -lF galaxy_collision_1 | head -20

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_04_03.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_04_03.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.mp4

# %%
# Playing MP4 movie file

# importing IPython.display
import IPython.display

# playing MP4 movie file
IPython.display.Video ('galaxy_collision_1.mp4')

# %%
# Downloading MP4 movie file to local computer

#
# If previous cell fails to play MP4 movie, then download MP4 movie file to your local computer and play the movie file on your local computer.
#

# importing google.colab
import google.colab.files

# downloading MP4 movie file
google.colab.files.download ('galaxy_collision_1.mp4')

# %% [markdown]
# # 7. Galaxy collision 1

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_05_00.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_05_00.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.bin

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_05_01.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_05_01.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.data

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_05_02.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_05_02.py

# %%
# Run this cell to find newly created files.

# !ls -lF galaxy_collision_2 | head -20

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_05_03.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_05_03.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.mp4

# %%
# Playing MP4 movie file

# importing IPython.display
import IPython.display

# playing MP4 movie file
IPython.display.Video ('galaxy_collision_2.mp4')

# %%
# Downloading MP4 movie file to local computer

#
# If previous cell fails to play MP4 movie, then download MP4 movie file to your local computer and play the movie file on your local computer.
#

# importing google.colab
import google.colab.files

# downloading MP4 movie file
google.colab.files.download ('galaxy_collision_2.mp4')

# %% [markdown]
# # 7. Galaxy collision 2

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_06_00.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_06_00.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.bin

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_06_01.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_06_01.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.data

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_06_02.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_06_02.py

# %%
# Run this cell to find newly created files.

# !ls -lF galaxy_collision_3 | head -20

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_06_03.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_06_03.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.mp4

# %%
# Playing MP4 movie file

# importing IPython.display
import IPython.display

# playing MP4 movie file
IPython.display.Video ('galaxy_collision_3.mp4')

# %%
# Downloading MP4 movie file to local computer

#
# If previous cell fails to play MP4 movie, then download MP4 movie file to your local computer and play the movie file on your local computer.
#

# importing google.colab
import google.colab.files

# downloading MP4 movie file
google.colab.files.download ('galaxy_collision_3.mp4')

# %% [markdown]
# # 7. Galaxy collision 3

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_07_00.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_07_00.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.bin

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_07_01.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_07_01.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.data

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_07_02.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_07_02.py

# %%
# Run this cell to find newly created files.

# !ls -lF galaxy_collision_4 | head -20

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py04_07_03.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py04_07_03.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.mp4

# %%
# Playing MP4 movie file

# importing IPython.display
import IPython.display

# playing MP4 movie file
IPython.display.Video ('galaxy_collision_4.mp4')

# %%
# Downloading MP4 movie file to local computer

#
# If previous cell fails to play MP4 movie, then download MP4 movie file to your local computer and play the movie file on your local computer.
#

# importing google.colab
import google.colab.files

# downloading MP4 movie file
google.colab.files.download ('galaxy_collision_4.mp4')

# %% [markdown]
# # End of this notebook
