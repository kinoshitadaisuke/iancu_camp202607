# %% [markdown]
# # IANCU Summer Camp for New Students 2026
#
# ## Introductory Python Programming 2: "Estimating the age of the Universe"
#
# ### Instructor: Kinoshita Daisuke
#
# ### July 2026

# %% [markdown]
# # 0. Installation of Python interpreter

# %%
# Run this cell to install Python 3.14

# !apt update
# !apt upgrade
# !apt install python3.14 python3.14-dev python3.14-full libpython3.14-dev
# !update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.14 1
# !wget https://bootstrap.pypa.io/get-pip.py
# !python3.14 get-pip.py

# %%
# Run this cell to check the version of Python interpreter and pip command

# !python3.14 --version
# !pip --version

# %%
# Run this cell to install external Python packages.

# !pip install matplotlib matplotlib-inline numpy scipy

# %% [markdown]
# # 1. Downloading a set of sample Python scripts for this course

# %%
# Run this cell to download a set of sample Python scripts for this course.

# !git clone https://github.com/kinoshitadaisuke/iancu_camp202607.git

# %%
# Run this cell to move to the directory for this session.

# %cd iancu_camp202607/py02

# %%
# Run this cell to show a list of files for this session.

# !ls -lF

# %% [markdown]
# # 2. Line fitting by least-square method

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py02_00_00.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py02_00_00.py

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py02_00_01.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py02_00_01.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.data

# %%
# Run this cell to show the content of the file.

# !cat line_01.data

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py02_00_02.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py02_00_02.py

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py02_00_03.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py02_00_03.py

# %%
# Run this cell to display PNG image.

# importing IPython.display module
import IPython.display

# displaying PNG file
IPython.display.Image ('line_01a.png')

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py02_00_04.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py02_00_04.py

# %%
# Run this cell to display PNG image.

# importing IPython.display module
import IPython.display

# displaying PNG file
IPython.display.Image ('line_01b.png')

# %% [markdown]
# # 3. One more example of line fitting using least-square method

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py02_01_00.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py02_01_00.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.data

# %%
# Run this cell to show the content of the file.

# !cat line_02.data

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py02_01_01.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py02_01_01.py

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py02_01_02.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py02_01_02.py

# %%
# Run this cell to display PNG image.

# importing IPython.display module
import IPython.display

# displaying PNG file
IPython.display.Image ('line_02a.png')

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py02_01_03.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py02_01_03.py

# %%
# Run this cell to display PNG image.

# importing IPython.display module
import IPython.display

# displaying PNG file
IPython.display.Image ('line_02b.png')

# %% [markdown]
# # 4. Estimating the age of the Universe

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py02_02_00.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py02_02_00.py

# %%
# Run this cell to find newly downloaded file.

# !ls -lF *.data

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py02_02_01.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py02_02_01.py

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py02_02_02.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py02_02_02.py

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py02_02_03.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py02_02_03.py

# %%
# Run this cell to find newly created file.

# !ls -lF *.data

# %%
# Run this cell to show the content of newly created file.

# !head -20 hyperleda_dv.data

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py02_02_04.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py02_02_04.py

# %%
# Run this cell to display PNG image.

# importing IPython.display module
import IPython.display

# displaying PNG file
IPython.display.Image ('hyperleda_hd1.png')

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py02_02_05.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py02_02_05.py

# %%
# Run this cell to display PNG image.

# importing IPython.display module
import IPython.display

# displaying PNG file
IPython.display.Image ('hyperleda_hd2.png')

# %%
# Run this cell to show the source code of the script.

# !cat camp_202607_py02_02_06.py

# %%
# Run this cell to execute the script.

# !python3.14 camp_202607_py02_02_06.py

# %% [markdown]
# # End of this notebook
